# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from sklearn.preprocessing import OneHotEncoder
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = [] 
labels = [] 
for dirname, _, filenames in os.walk('/Archive'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# []

# %%
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels

# %%
print('Dataset is Loaded')
print(df.head())
# Out:
# Dataset is Loaded
# Empty DataFrame
# Columns: [speech, label]
# Index: []

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
     y, sr = librosa.load(filename, duration=3, offset=0.5)
     mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
     return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727  ,   85.78295  ,   -2.1689117,   22.125532 ,
#         -14.757396 ,   11.051347 ,   12.412449 ,   -3.000262 ,
#           1.0844985,   11.078271 ,  -17.41966  ,   -8.093213 ,
#           6.5879736,   -4.2209525,   -9.15508  ,    3.5214796,
#         -13.186381 ,   14.078853 ,   19.66973  ,   22.725618 ,
#          32.57464  ,   16.325033 ,   -3.8427284,    0.8962967,
#         -11.239264 ,    6.653461 ,   -2.5883694,   -7.7140164,
#         -10.941657 ,   -2.4007552,   -5.2812862,    4.271157 ,
#         -11.202216 ,   -9.024621 ,   -3.666985 ,    4.8697433,
#          -1.6027987,    2.5600514,   11.454374 ,   11.233449 ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689117, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.8413284, 14.658875,...
# 2       [-340.11435, 53.796444, -14.267782, 20.884031,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.02505877, 8.431058, -...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.8675754...
# 5597    [-357.54886, 77.88605, -15.224756, 2.194633, -...
# 5598    [-353.1474, 101.68391, -14.175897, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.3469982, -1.4258989, ...
# Name: speech, Length: 5600, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
X = np.expand_dims(X, -1)
X.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

models = Sequential ([
    LSTM(123, return_sequences=False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0,2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax'),
])

models.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
models.summary()
# Out:
# 2024-08-12 02:30:06.357970: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-12 02:30:06.358116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-12 02:30:06.540519: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 123)            │        61,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         7,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,747 (280.26 KB)
#  Trainable params: 71,747 (280.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = models.fit(X, y, validation_split=0.2, epochs=100, batch_size=512, shuffle=True)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.3274 - loss: 1.8886 - val_accuracy: 0.0830 - val_loss: 1.8656
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.5327 - loss: 1.5805 - val_accuracy: 0.1241 - val_loss: 1.8096
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.6603 - loss: 1.1471 - val_accuracy: 0.2777 - val_loss: 1.4786
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.7161 - loss: 0.8271 - val_accuracy: 0.5580 - val_loss: 1.0535
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.7923 - loss: 0.5870 - val_accuracy: 0.6812 - val_loss: 0.8024
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.8401 - loss: 0.4472 - val_accuracy: 0.8134 - val_loss: 0.5906
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.8871 - loss: 0.3362 - val_accuracy: 0.8518 - val_loss: 0.4910
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9114 - loss: 0.2640 - val_accuracy: 0.8795 - val_loss: 0.3682
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9321 - loss: 0.2118 - val_accuracy: 0.9223 - val_loss: 0.2668
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9554 - loss: 0.1572 - val_accuracy: 0.9170 - val_loss: 0.2492
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9570 - loss: 0.1369 - val_accuracy: 0.9482 - val_loss: 0.1518
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.9557 - loss: 0.1275 - val_accuracy: 0.9670 - val_loss: 0.1083
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9746 - loss: 0.0988 - val_accuracy: 0.9571 - val_loss: 0.1352
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9733 - loss: 0.0973 - val_accuracy: 0.9634 - val_loss: 0.1039
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9801 - loss: 0.0691 - val_accuracy: 0.9679 - val_loss: 0.0891
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.9787 - loss: 0.0753 - val_accuracy: 0.9509 - val_loss: 0.1394
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9750 - loss: 0.0763 - val_accuracy: 0.9688 - val_loss: 0.0824
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9801 - loss: 0.0611 - val_accuracy: 0.9705 - val_loss: 0.0836
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9814 - loss: 0.0564 - val_accuracy: 0.9732 - val_loss: 0.0781
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9832 - loss: 0.0553 - val_accuracy: 0.9696 - val_loss: 0.0804
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9854 - loss: 0.0489 - val_accuracy: 0.9732 - val_loss: 0.0709
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9888 - loss: 0.0384 - val_accuracy: 0.9786 - val_loss: 0.0623
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9849 - loss: 0.0440 - val_accuracy: 0.9804 - val_loss: 0.0662
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9866 - loss: 0.0466 - val_accuracy: 0.9821 - val_loss: 0.0454
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9862 - loss: 0.0465 - val_accuracy: 0.9821 - val_loss: 0.0573
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9910 - loss: 0.0362 - val_accuracy: 0.9866 - val_loss: 0.0305
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9906 - loss: 0.0326 - val_accuracy: 0.9830 - val_loss: 0.0403
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.9884 - loss: 0.0331 - val_accuracy: 0.9821 - val_loss: 0.0504
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9851 - loss: 0.0390 - val_accuracy: 0.9848 - val_loss: 0.0386
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9938 - loss: 0.0225 - val_accuracy: 0.9884 - val_loss: 0.0268
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9921 - loss: 0.0266 - val_accuracy: 0.9786 - val_loss: 0.0609
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9938 - loss: 0.0258 - val_accuracy: 0.9866 - val_loss: 0.0280
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9926 - loss: 0.0236 - val_accuracy: 0.9768 - val_loss: 0.0532
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9883 - loss: 0.0302 - val_accuracy: 0.9750 - val_loss: 0.0654
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9904 - loss: 0.0247 - val_accuracy: 0.9884 - val_loss: 0.0368
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9920 - loss: 0.0252 - val_accuracy: 0.9911 - val_loss: 0.0264
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9915 - loss: 0.0288 - val_accuracy: 0.9821 - val_loss: 0.0426
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9940 - loss: 0.0222 - val_accuracy: 0.9964 - val_loss: 0.0171
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9953 - loss: 0.0162 - val_accuracy: 0.9830 - val_loss: 0.0373
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9954 - loss: 0.0170 - val_accuracy: 0.9964 - val_loss: 0.0131
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9974 - loss: 0.0113 - val_accuracy: 0.9937 - val_loss: 0.0166
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.9902 - val_loss: 0.0166
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9960 - loss: 0.0135 - val_accuracy: 0.9964 - val_loss: 0.0130
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9958 - loss: 0.0108 - val_accuracy: 0.9982 - val_loss: 0.0075
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.9970 - loss: 0.0126 - val_accuracy: 0.9982 - val_loss: 0.0101
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.9968 - loss: 0.0093 - val_accuracy: 0.9946 - val_loss: 0.0141
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9962 - loss: 0.0119 - val_accuracy: 0.9991 - val_loss: 0.0081
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 0.9991 - val_loss: 0.0048
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9969 - loss: 0.0080 - val_accuracy: 0.9982 - val_loss: 0.0058
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9974 - loss: 0.0082 - val_accuracy: 0.9973 - val_loss: 0.0079
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9929 - loss: 0.0261 - val_accuracy: 0.9741 - val_loss: 0.0684
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9834 - loss: 0.0605 - val_accuracy: 0.9902 - val_loss: 0.0262
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9904 - loss: 0.0313 - val_accuracy: 0.9920 - val_loss: 0.0265
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9914 - loss: 0.0276 - val_accuracy: 0.9955 - val_loss: 0.0199
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9971 - loss: 0.0152 - val_accuracy: 0.9911 - val_loss: 0.0197
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9957 - loss: 0.0132 - val_accuracy: 0.9991 - val_loss: 0.0062
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.9982 - val_loss: 0.0079
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9990 - loss: 0.0068 - val_accuracy: 0.9973 - val_loss: 0.0075
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9991 - loss: 0.0059 - val_accuracy: 0.9991 - val_loss: 0.0044
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9993 - loss: 0.0045 - val_accuracy: 0.9991 - val_loss: 0.0044
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.9911 - val_loss: 0.0188
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9982 - loss: 0.0064 - val_accuracy: 0.9991 - val_loss: 0.0028
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9978 - loss: 0.0073 - val_accuracy: 0.9982 - val_loss: 0.0050
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 0.9991 - val_loss: 0.0033
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9993 - loss: 0.0041 - val_accuracy: 0.9991 - val_loss: 0.0029
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9991 - val_loss: 0.0034
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.9991 - val_loss: 0.0021
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 0.9991 - val_loss: 0.0023
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9991 - val_loss: 0.0025
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9988 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0025
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9991 - val_loss: 0.0017
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 0.9991 - val_loss: 0.0022
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.9991 - val_loss: 0.0019
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9991 - val_loss: 0.0012
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 9.6035e-04
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 9.1032e-04
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.6167e-04
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9991 - val_loss: 9.3548e-04
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 6.9457e-04
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 5.8527e-04
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 6.1458e-04
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 5.3892e-04
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9999 - loss: 7.4948e-04 - val_accuracy: 1.0000 - val_loss: 4.1785e-04
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 1.0000 - loss: 8.0706e-04 - val_accuracy: 1.0000 - val_loss: 4.7158e-04
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.1702e-04
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.6843e-04
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 3.9728e-04
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 1.0000 - loss: 9.1554e-04 - val_accuracy: 1.0000 - val_loss: 4.0813e-04
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.8470e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.5198e-04
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 1.0000 - loss: 9.4452e-04 - val_accuracy: 1.0000 - val_loss: 3.8348e-04
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 1.0000 - loss: 7.2384e-04 - val_accuracy: 1.0000 - val_loss: 3.3130e-04
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 5.6009e-04
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 5.2714e-04
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 1.0000 - loss: 9.5093e-04 - val_accuracy: 1.0000 - val_loss: 6.0120e-04
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9991 - val_loss: 0.0020
